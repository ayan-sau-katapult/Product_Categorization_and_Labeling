# %%
import pandas as pd

df=pd.read_excel("Lenovo_Categorized.xlsx").drop("Unnamed: 0",axis=1)
df.head()
# Out:
#                                            lazy_href  \
# 0                    ThinkSystem 1Gb 2-port RJ45 LOM
# 1                    ThinkSystem 1Gb 4-port RJ45 LOM
# 2  ThinkSystem Broadcom 5720 1GbE RJ45 2-Port PCI...
# 3  ThinkSystem Broadcom 5719 1GbE RJ45 4-Port PCI...
# 4                   ThinkSystem 10Gb 2-port SFP+ LOM
#
#                                       lazy_href href             Category  \
# 0  https://www.lenovo.com/us/en/p/data-center-opt...  adapters and cables
# 1  https://www.lenovo.com/us/en/p/data-center-opt...  adapters and cables
# 2  https://www.lenovo.com/us/en/p/data-center-opt...  adapters and cables
# 3  https://www.lenovo.com/us/en/p/data-center-opt...  adapters and cables
# 4  https://www.lenovo.com/us/en/p/data-center-opt...  adapters and cables
#
#    Is_Leasable
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %%
df.shape
# Out:
# (3220, 4)

# %%
df.isnull().sum()
# Out:
# lazy_href           34
# lazy_href href      34
# Category          1080
# Is_Leasable       1080
# dtype: int64

# %%
df.groupby(["Category","Is_Leasable"]).count()
# Out:
#                                          lazy_href  lazy_href href
# Category                    Is_Leasable
# Cases and bags              0.0                147             147
# Chargers and Accessories    1.0                 67              67
# Computer Locks              0.0                 24              24
# Convenience Bundles         0.0                 42              42
# Data Storage                0.0                  9               9
# Desktop                     1.0                 74              74
# Docking stations for Cables 0.0                 20              20
# Furniture                   1.0                119             119
# Gaming Console              1.0                 40              40
# Graphics Card               0.0                 21              21
# Keyboard and Mouse          1.0                199             199
# Laptop                      1.0                160             160
# ...
