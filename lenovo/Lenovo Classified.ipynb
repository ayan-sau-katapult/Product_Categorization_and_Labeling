# %%
import glob
import pandas as pd

# get data file names
path =r'C:\Users\AyanSau\Desktop\lenovo\lenovo\Lenovo'
filenames = glob.glob(path + "/*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))

# Concatenate all data into one DataFrame
big_df = pd.concat(dfs, ignore_index=True)
big_df
# Out:
#                                        normal_image src  \
# 0     https://p1-ofp.static.pub/medias/bWFzdGVyfHJvb...
# 1     https://p1-ofp.static.pub/medias/bWFzdGVyfHJvb...
# 2     https://p1-ofp.static.pub/medias/bWFzdGVyfHJvb...
# 3     https://p1-ofp.static.pub/medias/bWFzdGVyfHJvb...
# 4     https://p1-ofp.static.pub/medias/bWFzdGVyfHJvb...
# ...                                                 ...
# 3215  https://p1-ofp.static.pub/medias/bWFzdGVyfHJvb...
# 3216  https://p1-ofp.static.pub/medias/bWFzdGVyfHJvb...
# 3217  https://p1-ofp.static.pub/medias/bWFzdGVyfHJvb...
# 3218  https://p1-ofp.static.pub/medias/bWFzdGVyfHJvb...
# 3219  https://p1-ofp.static.pub/medias/bWFzdGVyfHJvb...
#
#                                         hover_image src  \
# 0     https://p1-ofp.static.pub/medias/bWFzdGVyfHJvb...
# 1     https://p1-ofp.static.pub/medias/bWFzdGVyfHJvb...
# 2                                                   NaN
# 3                                                   NaN
# 4     https://p1-ofp.static.pub/medias/bWFzdGVyfHJvb...
# ...                                                 ...
# 3215  https://p1-ofp.static.pub/medias/bWFzdGVyfHJvb...
# 3216  https://p1-ofp.static.pub/medias/bWFzdGVyfHJvb...
# 3217  https://p1-ofp.static.pub/medias/bWFzdGVyfHJvb...
# 3218  https://p1-ofp.static.pub/medias/bWFzdGVyfHJvb...
# 3219  https://p1-ofp.static.pub/medias/bWFzdGVyfHJvb...
#
#                                               heart src  \
# 0     https://p1-ofp.static.pub/fes/cms/2020/12/25/7...
# 1     https://p1-ofp.static.pub/fes/cms/2020/12/25/7...
# 2                                                   NaN
# 3                                                   NaN
# 4     https://p1-ofp.static.pub/fes/cms/2020/12/25/7...
# ...                                                 ...
# 3215                                                NaN
# 3216                                                NaN
# 3217                                                NaN
# 3218                                                NaN
# 3219                                                NaN
#
#                              productGalleryOverride src  \
# 0     https://p2-ofp.static.pub/fes/cms/2021/07/06/2...
# 1     https://p2-ofp.static.pub/fes/cms/2021/07/06/2...
# 2                                                   NaN
# 3                                                   NaN
# 4     https://p2-ofp.static.pub/fes/cms/2021/07/06/2...
# ...                                                 ...
# 3215                                                NaN
# 3216                                                NaN
# 3217                                                NaN
# 3218                                                NaN
# 3219                                                NaN
#
#                            productGalleryOverride src 2  \
# 0     https://p3-ofp.static.pub/fes/cms/2021/07/06/e...
# 1     https://p3-ofp.static.pub/fes/cms/2021/07/06/e...
# 2                                                   NaN
# 3                                                   NaN
# 4     https://p3-ofp.static.pub/fes/cms/2021/07/06/e...
# ...                                                 ...
# 3215                                                NaN
# 3216                                                NaN
# 3217                                                NaN
# 3218                                                NaN
# 3219                                                NaN
#
#                            productGalleryOverride src 3  \
# 0     https://p2-ofp.static.pub/fes/cms/2021/07/06/w...
# 1     https://p2-ofp.static.pub/fes/cms/2021/07/06/w...
# 2                                                   NaN
# 3                                                   NaN
# 4     https://p2-ofp.static.pub/fes/cms/2021/07/06/w...
# ...                                                 ...
# 3215                                                NaN
# 3216                                                NaN
# 3217                                                NaN
# 3218                                                NaN
# 3219                                                NaN
#
#                                               lazy_href  \
# 0                       ThinkSystem 1Gb 2-port RJ45 LOM
# 1                       ThinkSystem 1Gb 4-port RJ45 LOM
# 2     ThinkSystem Broadcom 5720 1GbE RJ45 2-Port PCI...
# 3     ThinkSystem Broadcom 5719 1GbE RJ45 4-Port PCI...
# 4                      ThinkSystem 10Gb 2-port SFP+ LOM
# ...                                                 ...
# 3215  ThinkPad P1 Gen 4 Intel (16") - Mobile Worksta...
# 3216                    ThinkPad T15g Gen 2 Intel (15")
# 3217      ThinkPad P15 Intel (15") - Mobile Workstation
# 3218                    ThinkPad T15g Gen 2 Intel (15")
# 3219                    ThinkPad T15g Gen 2 Intel (15")
#
#                                          lazy_href href part_number 2  \
# 0     https://www.lenovo.com/us/en/p/data-center-opt...    7ZT7A00544
# 1     https://www.lenovo.com/us/en/p/data-center-opt...    7ZT7A00545
# 2     https://www.lenovo.com/us/en/p/data-center-opt...    7ZT7A00482
# 3     https://www.lenovo.com/us/en/p/data-center-opt...    7ZT7A00484
# 4     https://www.lenovo.com/us/en/p/data-center-opt...    7ZT7A00546
# ...                                                 ...           ...
# 3215  https://www.lenovo.com/us/en/p/laptops/thinkpa...           NaN
# 3216  https://www.lenovo.com/us/en/p/laptops/thinkpa...           NaN
# 3217  https://www.lenovo.com/us/en/p/laptops/thinkpa...           NaN
# 3218  https://www.lenovo.com/us/en/p/laptops/thinkpa...           NaN
# 3219  https://www.lenovo.com/us/en/p/laptops/thinkpa...           NaN
#
#                                             key_details  ...  \
# 0     Two copper-based Gigabit ports on a single PCI...  ...
# 1     ThinkSystem LOM adapters are cost-effective ad...  ...
# 2     Two copper-based Gigabit ports on a single PCI...  ...
# 3     Four copper-based Gigabit Ethernet ports on a ...  ...
# 4     ThinkSystem LOM adapters are cost-effective ad...  ...
# ...                                                 ...  ...
# 3215                                                NaN  ...
# 3216                                                NaN  ...
# 3217                                                NaN  ...
# 3218                                                NaN  ...
# 3219                                                NaN  ...
#
#      dcg__button href 2 copy-block 7 specs 2  \
# 0                   NaN          NaN     NaN
# 1                   NaN          NaN     NaN
# 2                   NaN          NaN     NaN
# 3                   NaN          NaN     NaN
# 4                   NaN          NaN     NaN
# ...                 ...          ...     ...
# 3215                NaN          NaN       ®
# 3216                NaN          NaN       ®
# 3217                NaN          NaN     NaN
# 3218                NaN          NaN       ®
# 3219                NaN          NaN       ®
#
#                                                 specs 4 specs 6 specs 8  \
# 0                                                   NaN     NaN     NaN
# 1                                                   NaN     NaN     NaN
# 2                                                   NaN     NaN     NaN
# 3                                                   NaN     NaN     NaN
# 4                                                   NaN     NaN     NaN
# ...                                                 ...     ...     ...
# 3215  Choice of high-end graphics options & security...     NaN     NaN
# 3216  Up to NVIDIA RTX 3080 discrete graphics and vi...     NaN     NaN
# 3217           Durable, secure, stylish, & customizable     NaN     NaN
# 3218  Up to NVIDIA RTX 3080 discrete graphics and vi...     NaN     NaN
# 3219  Up to NVIDIA RTX 3080 discrete graphics and vi...     NaN     NaN
#
#      specs 10 text 6 text 7 price 3
# 0         NaN    NaN    NaN     NaN
# 1         NaN    NaN    NaN     NaN
# 2         NaN    NaN    NaN     NaN
# 3         NaN    NaN    NaN     NaN
# 4         NaN    NaN    NaN     NaN
# ...       ...    ...    ...     ...
# 3215      NaN    NaN    NaN     NaN
# 3216      NaN    NaN    NaN     NaN
# 3217      NaN    NaN    NaN     NaN
# 3218      NaN    NaN    NaN     NaN
# 3219      NaN    NaN    NaN     NaN
#
# [3220 rows x 177 columns]

# %%
big_df.to_excel("big_df.xlsx")

# %%
df=pd.read_excel("big_df_final.xlsx").drop("Unnamed: 0",axis=1)
df
# Out:
#                                               lazy_href  \
# 0                       ThinkSystem 1Gb 2-port RJ45 LOM
# 1                       ThinkSystem 1Gb 4-port RJ45 LOM
# 2     ThinkSystem Broadcom 5720 1GbE RJ45 2-Port PCI...
# 3     ThinkSystem Broadcom 5719 1GbE RJ45 4-Port PCI...
# 4                      ThinkSystem 10Gb 2-port SFP+ LOM
# ...                                                 ...
# 3215  ThinkPad P1 Gen 4 Intel (16") - Mobile Worksta...
# 3216                    ThinkPad T15g Gen 2 Intel (15")
# 3217      ThinkPad P15 Intel (15") - Mobile Workstation
# 3218                    ThinkPad T15g Gen 2 Intel (15")
# 3219                    ThinkPad T15g Gen 2 Intel (15")
#
#                                          lazy_href href
# 0     https://www.lenovo.com/us/en/p/data-center-opt...
# 1     https://www.lenovo.com/us/en/p/data-center-opt...
# 2     https://www.lenovo.com/us/en/p/data-center-opt...
# 3     https://www.lenovo.com/us/en/p/data-center-opt...
# 4     https://www.lenovo.com/us/en/p/data-center-opt...
# ...                                                 ...
# 3215  https://www.lenovo.com/us/en/p/laptops/thinkpa...
# 3216  https://www.lenovo.com/us/en/p/laptops/thinkpa...
# 3217  https://www.lenovo.com/us/en/p/laptops/thinkpa...
# 3218  https://www.lenovo.com/us/en/p/laptops/thinkpa...
# 3219  https://www.lenovo.com/us/en/p/laptops/thinkpa...
#
# [3220 rows x 2 columns]
