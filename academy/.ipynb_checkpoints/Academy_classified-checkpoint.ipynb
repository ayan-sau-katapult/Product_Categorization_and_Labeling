# %%
import pandas as pd

df=pd.read_excel("PreProcess.xlsx").drop("Unnamed: 0",axis=1)
df
# Out:
#                                 product-card-simple-title  \
# 0       Columbia Sportswear Men's Dallas Cowboys PFG M...
# 1       Nike Men's Dallas Cowboys Air Zoom Pegasus 38 ...
# 2                        Logo Dallas Cowboys Stadium Seat
# 3       Victory Tailgate Dallas Cowboys Bean Bag Toss ...
# 4       NFL Toddler Girls' New Orleans Saints Cheer Ca...
# ...                                                   ...
# 158592  Game Winner® Women's Midweight Fleece Beanie  ...
# 158593  BCG™ Women's Lifestyle Motto Long Sleeve Crew ...
# 158594  BCG Women's Lifestyle Motto Jogger Pant       ...
# 158595  BCG™ Women's Lifestyle Ponte Legging          ...
# 158596  BCG™ Women's Lifestyle Texture Block Hoodie   ...
#
#                                                       url       Category  \
# 0       https://www.academy.com/shop/pdp/columbia-spor...            NaN
# 1       https://www.academy.com/shop/pdp/nike-mens-dal...            NaN
# ...

# %%
df.fillna("None")
# Out:
#                                 product-card-simple-title  \
# 0       Columbia Sportswear Men's Dallas Cowboys PFG M...
# 1       Nike Men's Dallas Cowboys Air Zoom Pegasus 38 ...
# 2                        Logo Dallas Cowboys Stadium Seat
# 3       Victory Tailgate Dallas Cowboys Bean Bag Toss ...
# 4       NFL Toddler Girls' New Orleans Saints Cheer Ca...
# ...                                                   ...
# 158592  Game Winner® Women's Midweight Fleece Beanie  ...
# 158593  BCG™ Women's Lifestyle Motto Long Sleeve Crew ...
# 158594  BCG Women's Lifestyle Motto Jogger Pant       ...
# 158595  BCG™ Women's Lifestyle Ponte Legging          ...
# 158596  BCG™ Women's Lifestyle Texture Block Hoodie   ...
#
#                                                       url       Category  \
# 0       https://www.academy.com/shop/pdp/columbia-spor...           None
# 1       https://www.academy.com/shop/pdp/nike-mens-dal...           None
# ...

# %%
def categorize(string):
    string= "".join(str(string).split())
    if string=="None":
        if "shirt" in string or "jersey" in string or "cap" in string or :
            return "apparel"
