# %%
import glob
import pandas as pd

# get data file names
path =r'C:\Users\AyanSau\Desktop\Weber-Stephen\Weber-Stephen'
filenames = glob.glob(path + "/*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))

# Concatenate all data into one DataFrame
big_df = pd.concat(dfs, ignore_index=True)
big_df
# Out:
#     web-scraper-order                              web-scraper-start-url  \
# 0      1633010874-145  https://www.weber.com/US/en/accessories/access...
# 1      1633010874-142  https://www.weber.com/US/en/accessories/access...
# 2      1633010874-156  https://www.weber.com/US/en/accessories/access...
# 3      1633010874-161  https://www.weber.com/US/en/accessories/access...
# 4      1633010874-155  https://www.weber.com/US/en/accessories/access...
# ..                ...                                                ...
# 821      1632842677-6  https://www.weber.com/US/en/grills/gas-grills/...
# 822      1632842677-7  https://www.weber.com/US/en/grills/gas-grills/...
# 823      1632842677-2  https://www.weber.com/US/en/grills/gas-grills/...
# 824      1632842677-8  https://www.weber.com/US/en/grills/gas-grills/...
# 825      1632842677-4  https://www.weber.com/US/en/grills/gas-grills/...
#
#                                                    nnn  \
# 0    Premium Grill Cover - Genesis II and LX 400 se...
# 1    Premium Grill Cover - SmokeFire EX4 Wood Fired...
# 2    Premium Carry Bag - Smokey Joe® series portabl...
# 3                    Grill Cover - 18" charcoal grills
# 4            Premium Grill Cover - 26" charcoal grills
# ..                                                 ...
# 821                                                NaN
# 822                                                NaN
# 823                                                NaN
# 824                                                NaN
# 825                                                NaN
#
#                                             name
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 821                    Spirit SX-315 Smart Grill
# 822  Genesis II EX-315 Smart Grill (Natural Gas)
# 823  Genesis II SX-335 Smart Grill (Natural Gas)
# 824      Spirit SX-315 Smart Grill (Natural Gas)
# 825  Genesis II EX-335 Smart Grill (Natural Gas)
#
# [826 rows x 4 columns]

# %%
big_df.isnull().sum()
# Out:
# web-scraper-order          0
# web-scraper-start-url      0
# nnn                        8
# name                     818
# dtype: int64

# %%
big_df['name']=big_df['name'].fillna(big_df['nnn'])
big_df=big_df.drop("nnn",axis=1)

# %%
big_df
# Out:
#     web-scraper-order                              web-scraper-start-url  \
# 0      1633010874-145  https://www.weber.com/US/en/accessories/access...
# 1      1633010874-142  https://www.weber.com/US/en/accessories/access...
# 2      1633010874-156  https://www.weber.com/US/en/accessories/access...
# 3      1633010874-161  https://www.weber.com/US/en/accessories/access...
# 4      1633010874-155  https://www.weber.com/US/en/accessories/access...
# ..                ...                                                ...
# 821      1632842677-6  https://www.weber.com/US/en/grills/gas-grills/...
# 822      1632842677-7  https://www.weber.com/US/en/grills/gas-grills/...
# 823      1632842677-2  https://www.weber.com/US/en/grills/gas-grills/...
# 824      1632842677-8  https://www.weber.com/US/en/grills/gas-grills/...
# 825      1632842677-4  https://www.weber.com/US/en/grills/gas-grills/...
#
#                                                   name
# 0    Premium Grill Cover - Genesis II and LX 400 se...
# 1    Premium Grill Cover - SmokeFire EX4 Wood Fired...
# 2    Premium Carry Bag - Smokey Joe® series portabl...
# 3                    Grill Cover - 18" charcoal grills
# 4            Premium Grill Cover - 26" charcoal grills
# ..                                                 ...
# 821                          Spirit SX-315 Smart Grill
# 822        Genesis II EX-315 Smart Grill (Natural Gas)
# 823        Genesis II SX-335 Smart Grill (Natural Gas)
# 824            Spirit SX-315 Smart Grill (Natural Gas)
# 825        Genesis II EX-335 Smart Grill (Natural Gas)
#
# [826 rows x 3 columns]

# %%
big_df.isnull().sum()
# Out:
# web-scraper-order        0
# web-scraper-start-url    0
# name                     0
# dtype: int64

# %%
big_df.to_excel("big_df.xlsx")
