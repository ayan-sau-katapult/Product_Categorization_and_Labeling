# %%
import pandas as pd

df=pd.read_excel("Shark-Ninja.xlsx")
df
# Out:
#       Unnamed: 0 web-scraper-order  \
# 0              0     1631788339-76
# 1              1    1631788339-138
# 2              2    1631788339-155
# 3              3     1631788339-98
# 4              4     1631788339-43
# ...          ...               ...
# 1140        1140               NaN
# 1141        1141               NaN
# 1142        1142               NaN
# 1143        1143               NaN
# 1144        1144               NaN
#
#                                   web-scraper-start-url  \
# 0     https://www.ninjakitchen.com/ninjaus/parts_acc...
# 1     https://www.ninjakitchen.com/ninjaus/parts_acc...
# 2     https://www.ninjakitchen.com/ninjaus/parts_acc...
# 3     https://www.ninjakitchen.com/ninjaus/parts_acc...
# 4     https://www.ninjakitchen.com/ninjaus/parts_acc...
# ...                                                 ...
# 1140                                                NaN
# 1141                                                NaN
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# web-scraper-order        36
# web-scraper-start-url    36
# name                      0
# dtype: int64
