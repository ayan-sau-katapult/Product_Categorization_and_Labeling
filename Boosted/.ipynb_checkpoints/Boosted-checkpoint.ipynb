# %%
import glob
import pandas as pd

# get data file names
path =r'C:\Users\AyanSau\Desktop\Boosted\Boosted'
filenames = glob.glob(path + "/*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))

# Concatenate all data into one DataFrame
big_df = pd.concat(dfs, ignore_index=True)
big_df
# Out:
#    web-scraper-order                              web-scraper-start-url  \
# 0      1633590755-41     https://boostedusa.com/collections/accessories
# 1      1633590755-14     https://boostedusa.com/collections/accessories
# 2      1633590755-20     https://boostedusa.com/collections/accessories
# 3      1633590755-16     https://boostedusa.com/collections/accessories
# 4      1633590755-15     https://boostedusa.com/collections/accessories
# ..               ...                                                ...
# 79      1633590570-4  https://boostedusa.com/collections/electric-sk...
# 80     1633592233-84     https://boostedusa.com/products/boosted-mini-s
# 81     1633592209-83       https://boostedusa.com/products/boosted-plus
# 82     1633591292-81        https://boostedusa.com/products/boosted-rev
# 83     1633592207-82    https://boostedusa.com/products/boosted-stealth
#
#                                    name
# 0   Boosted Motor Driver Screws / Wings
# 1                    Boosted Skate Tool
# 2   Loaded Caguama 85's Complete Purple
# 3      Boa Constrictor Wheels 100mm 76a
# 4                       CaliRides 105's
# ..                                  ...
# 79                       Boosted Mini S
# 80                       Boosted Mini S
# 81                      Boosted Plus V3
# 82         Boosted Rev Electric Scooter
# 83                      Boosted Stealth
#
# [84 rows x 3 columns]

# %%
def categorized(string):
    return string.split("/")[-1]

big_df["Category"]=big_df["web-scraper-start-url"].apply(categorized)
big_df
# Out:
#    web-scraper-order                              web-scraper-start-url  \
# 0      1633590755-41     https://boostedusa.com/collections/accessories
# 1      1633590755-14     https://boostedusa.com/collections/accessories
# 2      1633590755-20     https://boostedusa.com/collections/accessories
# 3      1633590755-16     https://boostedusa.com/collections/accessories
# 4      1633590755-15     https://boostedusa.com/collections/accessories
# ..               ...                                                ...
# 79      1633590570-4  https://boostedusa.com/collections/electric-sk...
# 80     1633592233-84     https://boostedusa.com/products/boosted-mini-s
# 81     1633592209-83       https://boostedusa.com/products/boosted-plus
# 82     1633591292-81        https://boostedusa.com/products/boosted-rev
# 83     1633592207-82    https://boostedusa.com/products/boosted-stealth
#
#                                    name              Category
# 0   Boosted Motor Driver Screws / Wings           accessories
# 1                    Boosted Skate Tool           accessories
# 2   Loaded Caguama 85's Complete Purple           accessories
# 3      Boa Constrictor Wheels 100mm 76a           accessories
# 4                       CaliRides 105's           accessories
# ..                                  ...                   ...
# 79                       Boosted Mini S  electric-skateboards
# 80                       Boosted Mini S        boosted-mini-s
# 81                      Boosted Plus V3          boosted-plus
# 82         Boosted Rev Electric Scooter           boosted-rev
# 83                      Boosted Stealth       boosted-stealth
#
# [84 rows x 4 columns]

# %%
big_df.to_excel("boosted.xlsx")
