# %%
import pandas as pd

df=pd.read_excel("data.xlsx").drop("Unnamed: 0",axis=1)
df
# Out:
#       web-scraper-order                              web-scraper-start-url  \
# 0       1630601075-8679  https://www.potterybarn.com/shop/bath/all-bath...
# 1       1630601075-8626  https://www.potterybarn.com/shop/bath/all-bath...
# 2       1630601075-8597  https://www.potterybarn.com/shop/bath/all-bath...
# 3       1630601075-8564  https://www.potterybarn.com/shop/bath/all-bath...
# 4       1630601075-8590  https://www.potterybarn.com/shop/bath/all-bath...
# ...                 ...                                                ...
# 15466  1630605169-11619  https://www.potterybarn.com/shop/window-treatm...
# 15467  1630605169-11546  https://www.potterybarn.com/shop/window-treatm...
# 15468  1630605169-11518  https://www.potterybarn.com/shop/window-treatm...
# 15469  1630605169-11577  https://www.potterybarn.com/shop/window-treatm...
# 15470  1630605169-11536  https://www.potterybarn.com/shop/window-treatm...
#
#                                                     name  \
# 0             Jacquelyn Medallion Organic Shower Curtain
# 1                            Lila Organic Shower Curtain
# 2              Classic Double Wide Organic Loop Bath Mat
# 3                          Aerospin™ Luxe Organic Towels
# 4           Hydrocotton Organic Towel Bundle - Set of 12
# ...                                                  ...
# 15466       Polished Nickel Glass Oval Finial - Set of 2
# 15467             Cast Iron Black Ball Finial - Set of 2
# 15468         400-Thread-Count Organic Percale Sheet Set
# 15469        Antique Bronze Glass Ball Finial - Set of 2
# 15470  Antique Bronze Room Darkening Curtain Rod & Wa...
#
#                                     Category Is_Leasable
# 0                       bath-all-bath-linens       False
# 1                       bath-all-bath-linens       False
# 2                       bath-all-bath-linens       False
# 3                       bath-all-bath-linens       False
# 4                       bath-all-bath-linens       False
# ...                                      ...         ...
# 15466  window-treatments-all-window-hardware       False
# 15467  window-treatments-all-window-hardware       False
# 15468  window-treatments-all-window-hardware       False
# 15469  window-treatments-all-window-hardware       False
# 15470  window-treatments-all-window-hardware       False
#
# [15471 rows x 5 columns]

# %%
set(df["Is_Leasable"].tolist())
# Out:
# {False, 'Not_Decided', True}

# %%
df_temp=df[df["Is_Leasable"]=='Not_Decided']

# %%
def is_leasable(string):
    string= "".join(str(string).split())
    if "Table" in string or "Chair" in string or "Mirror" in string or "Bookcase" in string or "Cabinet" in string or "Bench" in string or "Mirror" in string or "Fan" in string and "Tablet" not in string:
        return True
    else:
        return False

# %%
df_temp["Is_Leasable"]=df_temp["name"].apply(is_leasable)
# Out:
# <ipython-input-13-3c85ed1d85de>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp["Is_Leasable"]=df_temp["name"].apply(is_leasable)

# %%
df_temp
# Out:
#       web-scraper-order                              web-scraper-start-url  \
# 8222    1630645709-6567  https://www.potterybarn.com/shop/organization/...
# 8224    1630645709-6618  https://www.potterybarn.com/shop/organization/...
# 8225    1630645709-6371  https://www.potterybarn.com/shop/organization/...
# 8226    1630645709-6619  https://www.potterybarn.com/shop/organization/...
# 8227    1630645709-6412  https://www.potterybarn.com/shop/organization/...
# ...                 ...                                                ...
# 12161   1630598299-7125  https://www.potterybarn.com/shop/lighting/outd...
# 12162   1630598299-7177  https://www.potterybarn.com/shop/lighting/outd...
# 12163   1630598299-7027  https://www.potterybarn.com/shop/lighting/outd...
# 12164   1630598299-7120  https://www.potterybarn.com/shop/lighting/outd...
# 12165   1630598299-7044  https://www.potterybarn.com/shop/lighting/outd...
#
#                                                     name  \
# 8222                              Trenton File Organizer
# 8224                  Marble Desk Accessories Collection
# 8225                   Warren 32" x 67" Etagere Bookcase
# 8226                              Bedford Desk Organizer
# 8227                       Acrylic Memo Tablet with Pens
# ...                                                  ...
# 12161                                  Lula Glass Sconce
# 12162             96" Stellar Indoor/Outdoor Ceiling Fan
# 12163         400-Thread-Count Organic Percale Sheet Set
# 12164                              Belvedere Flush Mount
# 12165  Big Sur Square Arm Upholstered Sofa Double Wid...
#
#                                       Category  Is_Leasable
# 8222        organization-home-office-solutions        False
# 8224        organization-home-office-solutions        False
# 8225        organization-home-office-solutions         True
# 8226        organization-home-office-solutions        False
# 8227        organization-home-office-solutions         True
# ...                                        ...          ...
# 12161  lighting-outdoor-lighting-string-lights        False
# 12162  lighting-outdoor-lighting-string-lights         True
# 12163  lighting-outdoor-lighting-string-lights        False
# 12164  lighting-outdoor-lighting-string-lights        False
# 12165  lighting-outdoor-lighting-string-lights        False
#
# [1649 rows x 5 columns]
