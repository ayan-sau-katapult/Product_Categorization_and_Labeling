# %%
import glob
import pandas as pd

# get data file names
path =r'C:\Users\AyanSau\Desktop\Pottery Barn\CSV FILES FROM SCRAPPING\Mirror and Art'
filenames = glob.glob(path + "/*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))

# Concatenate all data into one DataFrame
big_frame = pd.concat(dfs, ignore_index=True)

# %%
dfs[0]["Category"]=dfs[0]["web-scraper-start-url"].apply(lambda x:x.split("/")[4]+x.split("/")[5])
dfs[0]["IsLeasable"]=False
dfs[0]
# Out:
#      web-scraper-order                              web-scraper-start-url  \
# 0      1630642619-3096  https://www.potterybarn.com/shop/mirrors-wall-...
# 1      1630642619-2575  https://www.potterybarn.com/shop/mirrors-wall-...
# 2      1630642619-3624  https://www.potterybarn.com/shop/mirrors-wall-...
# 3      1630642619-3111  https://www.potterybarn.com/shop/mirrors-wall-...
# 4      1630642619-3466  https://www.potterybarn.com/shop/mirrors-wall-...
# ...                ...                                                ...
# 1277   1630642619-3525  https://www.potterybarn.com/shop/mirrors-wall-...
# 1278   1630642619-2583  https://www.potterybarn.com/shop/mirrors-wall-...
# 1279   1630642619-3232  https://www.potterybarn.com/shop/mirrors-wall-...
# 1280   1630642619-3449  https://www.potterybarn.com/shop/mirrors-wall-...
# 1281   1630642619-2886  https://www.potterybarn.com/shop/mirrors-wall-...
#
#                                            name                 Category  \
# ...

# %%
dfs[1]["Category"]=dfs[1]["web-scraper-start-url"].apply(lambda x:x.split("/")[4]+x.split("/")[5])
dfs[1]["IsLeasable"]=True
dfs[1]
# Out:
#     web-scraper-order                              web-scraper-start-url  \
# 0     1630642138-2340  https://www.potterybarn.com/shop/mirrors-wall-...
# 1     1630642138-2347  https://www.potterybarn.com/shop/mirrors-wall-...
# 2     1630642138-2330  https://www.potterybarn.com/shop/mirrors-wall-...
# 3     1630642138-2305  https://www.potterybarn.com/shop/mirrors-wall-...
# 4     1630642138-2295  https://www.potterybarn.com/shop/mirrors-wall-...
# ..                ...                                                ...
# 214   1630642138-2348  https://www.potterybarn.com/shop/mirrors-wall-...
# 215   1630642138-2204  https://www.potterybarn.com/shop/mirrors-wall-...
# 216   1630642138-2358  https://www.potterybarn.com/shop/mirrors-wall-...
# 217   1630642138-2200  https://www.potterybarn.com/shop/mirrors-wall-...
# 218   1630642138-2202  https://www.potterybarn.com/shop/mirrors-wall-...
#
#                                                   name  \
# ...

# %%
# Concatenate all data into one DataFrame
big_frame = pd.concat(dfs, ignore_index=True)

# %%
big_frame
# Out:
#      web-scraper-order                              web-scraper-start-url  \
# 0      1630642619-3096  https://www.potterybarn.com/shop/mirrors-wall-...
# 1      1630642619-2575  https://www.potterybarn.com/shop/mirrors-wall-...
# 2      1630642619-3624  https://www.potterybarn.com/shop/mirrors-wall-...
# 3      1630642619-3111  https://www.potterybarn.com/shop/mirrors-wall-...
# 4      1630642619-3466  https://www.potterybarn.com/shop/mirrors-wall-...
# ...                ...                                                ...
# 1496   1630642138-2348  https://www.potterybarn.com/shop/mirrors-wall-...
# 1497   1630642138-2204  https://www.potterybarn.com/shop/mirrors-wall-...
# 1498   1630642138-2358  https://www.potterybarn.com/shop/mirrors-wall-...
# 1499   1630642138-2200  https://www.potterybarn.com/shop/mirrors-wall-...
# 1500   1630642138-2202  https://www.potterybarn.com/shop/mirrors-wall-...
#
#                                       name                     Category  \
# ...

# %%
link=big_frame["web-scraper-start-url"][0]
link
# Out:
# 'https://www.potterybarn.com/shop/mirrors-wall-art/all-art/?cm_type=gnav'

# %%
link.split("/")[4]
# Out:
# 'mirrors-wall-art'

# %%
m=[]
for link in big_frame["web-scraper-start-url"].tolist():
    m.append(link.split("/")[4]+"-"+link.split("/")[5])
    
set(m)
# Out:
# {'mirrors-wall-art-all-art', 'mirrors-wall-art-all-mirrors'}

# %%
#big_frame["Category"]=big_frame["web-scraper-start-url"].apply(lambda x:x.split("/")[4]+x.split("/")[5])

# %%
#import numpy as np

#big_frame['IsLeasable'] = np.where(big_frame['Category']== 'mirrors-wall-art-all-mirrors', True, False)

# %%
#big_frame["IsLeasable"]=True

# %%
#big_frame[big_frame["IsLeasable"]==True]
# Out:
# Empty DataFrame
# Columns: [web-scraper-order, web-scraper-start-url, name, Category, IsLeasable]
# Index: []

# %%
big_frame.to_excel("Mirror_and_art.xlsx")
