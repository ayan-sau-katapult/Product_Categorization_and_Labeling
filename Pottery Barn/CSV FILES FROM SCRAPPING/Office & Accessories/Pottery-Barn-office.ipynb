# %%
import glob
import pandas as pd

# get data file names
path =r'C:\Users\AyanSau\Desktop\Pottery Barn\CSV FILES FROM SCRAPPING\Office & Accessories'
filenames = glob.glob(path + "/*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))

# Concatenate all data into one DataFrame
big_frame = pd.concat(dfs, ignore_index=True)

# %%
dfs[0]["Category"]=dfs[0]["web-scraper-start-url"].apply(lambda x:x.split("/")[4]+x.split("/")[5])
dfs[0]["IsLeasable"]=True
dfs[0]
# Out:
#     web-scraper-order                              web-scraper-start-url  \
# 0     1630645709-6567  https://www.potterybarn.com/shop/organization/...
# 1     1630645709-6572  https://www.potterybarn.com/shop/organization/...
# 2     1630645709-6618  https://www.potterybarn.com/shop/organization/...
# 3     1630645709-6371  https://www.potterybarn.com/shop/organization/...
# 4     1630645709-6619  https://www.potterybarn.com/shop/organization/...
# ..                ...                                                ...
# 400   1630645709-6325  https://www.potterybarn.com/shop/organization/...
# 401   1630645709-6547  https://www.potterybarn.com/shop/organization/...
# 402   1630645709-6722  https://www.potterybarn.com/shop/organization/...
# 403   1630645709-6573  https://www.potterybarn.com/shop/organization/...
# 404   1630645709-6615  https://www.potterybarn.com/shop/organization/...
#
#                                                 name  \
# 0                             Trenton File Organizer
# 1               Malcolm 30" Writing Desk with Drawer
# 2                 Marble Desk Accessories Collection
# 3                  Warren 32" x 67" Etagere Bookcase
# 4                             Bedford Desk Organizer
# ..                                               ...
# 400       400-Thread-Count Organic Percale Sheet Set
# 401            Bedford 52" Writing Desk with Drawers
# 402  Gia Leather Desk Accessories Collection - Green
# 403              Nash Faux Leather Swivel Desk Chair
# 404                                Maiden Table Lamp
#
#                               Category  IsLeasable
# 0    organizationhome-office-solutions        True
# 1    organizationhome-office-solutions        True
# 2    organizationhome-office-solutions        True
# 3    organizationhome-office-solutions        True
# 4    organizationhome-office-solutions        True
# ..                                 ...         ...
# 400  organizationhome-office-solutions        True
# 401  organizationhome-office-solutions        True
# 402  organizationhome-office-solutions        True
# 403  organizationhome-office-solutions        True
# 404  organizationhome-office-solutions        True
#
# [405 rows x 5 columns]

# %%
dfs[1]["Category"]=dfs[1]["web-scraper-start-url"].apply(lambda x:x.split("/")[4]+x.split("/")[5])
dfs[1]["IsLeasable"]=False
dfs[1]
# Out:
#     web-scraper-order                              web-scraper-start-url  \
# 0     1630646631-8087  https://www.potterybarn.com/shop/organization/...
# 1     1630646631-8092  https://www.potterybarn.com/shop/organization/...
# 2     1630646631-8034  https://www.potterybarn.com/shop/organization/...
# 3     1630646631-7983  https://www.potterybarn.com/shop/organization/...
# 4     1630646631-7952  https://www.potterybarn.com/shop/organization/...
# ..                ...                                                ...
# 154   1630646631-7941  https://www.potterybarn.com/shop/organization/...
# 155   1630646631-7961  https://www.potterybarn.com/shop/organization/...
# 156   1630646631-8027  https://www.potterybarn.com/shop/organization/...
# 157   1630646631-7989  https://www.potterybarn.com/shop/organization/...
# 158   1630646631-8033  https://www.potterybarn.com/shop/organization/...
#
#                                                   name  \
# 0                         Saddle Leather Toiletry Case
# 1                            Pretty Useful Eyebrow Kit
# 2                         Mark & Graham Commute Clutch
# 3                                The Prepster Backpack
# 4    Big Sur Square Arm Upholstered Sofa Double Wid...
# ..                                                 ...
# 154                                      Farmhouse Bed
# 155          McKenna Leather Small Travel Jewelry Case
# 156                                  Canvas Lunch Tote
# 157      Greenpoint Waxed Canvas Picnic Bag, Set for 2
# 158                                Bric's X-Bag Duffle
#
#                                 Category  IsLeasable
# 0    organizationall-luggage-travel-bags       False
# 1    organizationall-luggage-travel-bags       False
# 2    organizationall-luggage-travel-bags       False
# 3    organizationall-luggage-travel-bags       False
# 4    organizationall-luggage-travel-bags       False
# ..                                   ...         ...
# 154  organizationall-luggage-travel-bags       False
# 155  organizationall-luggage-travel-bags       False
# 156  organizationall-luggage-travel-bags       False
# 157  organizationall-luggage-travel-bags       False
# 158  organizationall-luggage-travel-bags       False
#
# [159 rows x 5 columns]

# %%
dfs[2]["Category"]=dfs[2]["web-scraper-start-url"].apply(lambda x:x.split("/")[4]+x.split("/")[5])
dfs[2]["IsLeasable"]=True
dfs[2]
# Out:
#      web-scraper-order                              web-scraper-start-url  \
# 0      1630646167-7459  https://www.potterybarn.com/shop/organization/...
# 1      1630646167-7329  https://www.potterybarn.com/shop/organization/...
# 2      1630646167-7044  https://www.potterybarn.com/shop/organization/...
# 3      1630646167-7816  https://www.potterybarn.com/shop/organization/...
# 4      1630646167-6883  https://www.potterybarn.com/shop/organization/...
# ...                ...                                                ...
# 1205   1630646167-7921  https://www.potterybarn.com/shop/organization/...
# 1206   1630646167-6751  https://www.potterybarn.com/shop/organization/...
# 1207   1630646167-6793  https://www.potterybarn.com/shop/organization/...
# 1208   1630646167-7661  https://www.potterybarn.com/shop/organization/...
# 1209   1630646167-7347  https://www.potterybarn.com/shop/organization/...
#
#                                                 name  \
# 0                        60" Wardrobe Storage Closet
# 1     Lorraine Tufted Upholstered King Storage Bench
# 2                                Marlow Storage Cube
# 3     Mission Modular System Collection, Double Hook
# 4                   Handcrafted Wooden Cubby Display
# ...                                              ...
# 1205        Cambria Stoneware Kitchen Utensil Holder
# 1206                   Aubrey Shelf with Closet Rail
# 1207                        Under the Vanity Storage
# 1208                           Mabel Navy Duffle Bag
# 1209   Mission Modular System Collection, Popup Desk
#
#                                     Category  IsLeasable
# 0     organizationall-home-storage-solutions        True
# 1     organizationall-home-storage-solutions        True
# 2     organizationall-home-storage-solutions        True
# 3     organizationall-home-storage-solutions        True
# 4     organizationall-home-storage-solutions        True
# ...                                      ...         ...
# 1205  organizationall-home-storage-solutions        True
# 1206  organizationall-home-storage-solutions        True
# 1207  organizationall-home-storage-solutions        True
# 1208  organizationall-home-storage-solutions        True
# 1209  organizationall-home-storage-solutions        True
#
# [1210 rows x 5 columns]

# %%
m=[]
for link in big_frame["web-scraper-start-url"].tolist():
    m.append(link.split("/")[4]+"-"+link.split("/")[5])
    
set(m)
# Out:
# {'organization-all-home-storage-solutions',
#  'organization-all-luggage-travel-bags',
#  'organization-home-office-solutions'}

# %%
big_frame = pd.concat(dfs, ignore_index=True)

# %%
set(big_frame["IsLeasable"].tolist())
# Out:
# {False, True}

# %%
link=big_frame["web-scraper-start-url"][0]
link
# Out:
# 'https://www.potterybarn.com/shop/lighting/all-lighting/?cm_type=gnav'

# %%
link.split("/")[4]
# Out:
# 'lighting'

# %%
m=[]
for link in big_frame["web-scraper-start-url"].tolist():
    m.append(link.split("/")[4]+"-"+link.split("/")[5])
    
set(m)
# Out:
# {'lighting-all-lighting'}

# %%
big_frame["Category"]=big_frame["web-scraper-start-url"].apply(lambda x:x.split("/")[4])

# %%
big_frame["IsLeasable"]=True

# %%
big_frame
# Out:
#      web-scraper-order                              web-scraper-start-url  \
# 0     1630605611-12578  https://www.potterybarn.com/shop/lighting/all-...
# 1     1630605611-12625  https://www.potterybarn.com/shop/lighting/all-...
# 2     1630605611-11735  https://www.potterybarn.com/shop/lighting/all-...
# 3     1630605611-12228  https://www.potterybarn.com/shop/lighting/all-...
# 4     1630605611-11911  https://www.potterybarn.com/shop/lighting/all-...
# ...                ...                                                ...
# 1008  1630605611-12509  https://www.potterybarn.com/shop/lighting/all-...
# 1009  1630605611-12394  https://www.potterybarn.com/shop/lighting/all-...
# 1010  1630605611-12607  https://www.potterybarn.com/shop/lighting/all-...
# 1011  1630605611-12241  https://www.potterybarn.com/shop/lighting/all-...
# 1012  1630605611-11928  https://www.potterybarn.com/shop/lighting/all-...
#
#                                                    name  Category  IsLeasable
# 0                                       Adele Task Lamp  lighting        True
# 1                                     Autumn Table Lamp  lighting        True
# 2                       Lockhart Forged Iron Chandelier  lighting        True
# 3                                         Colton Sconce  lighting        True
# 4                       Amelie Milk Glass Single Sconce  lighting        True
# ...                                                 ...       ...         ...
# 1008                               Salvatore Table Lamp  lighting        True
# 1009          G25 Milk Glass Globe LED Bulb - Pack of 2  lighting        True
# 1010             A19 Silver-Tipped LED Bulb - Pack of 2  lighting        True
# 1011  Articulating Arm Curved Metal Bell Plug-In Sconce  lighting        True
# 1012                                   Basic Cord Cover  lighting        True
#
# [1013 rows x 5 columns]

# %%
big_frame.to_excel("office_accessories.xlsx")
