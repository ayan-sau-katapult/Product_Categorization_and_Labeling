# %%
import glob
import pandas as pd

# get data file names
path =r'C:\Users\AyanSau\Desktop\Office-Depot\Final-Folder'
filenames = glob.glob(path + "/*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename,encoding='ISO-8859-1'))

# Concatenate all data into one DataFrame
big_df = pd.concat(dfs, ignore_index=True)
big_df
# Out:
#                                               ï»¿name ï»¿web-scraper-order  \
# 0         \nWorkProÂ® 1000 Series Ergonomic Mesh/Mesh                  NaN
# 1              \nRealspaceâ¢ Anti-Fatigue Mat For...                  NaN
# 2                   \nGaiam Balance Ball Chair, Black                  NaN
# 3       \nSertaÂ® iComfort For WorkProÂ® High-Back...                  NaN
# 4                \nEpsonÂ® WorkForceÂ® Pro WF-3820...                  NaN
# ...                                               ...                  ...
# 339532                                            NaN     1631830141-19610
# 339533                                            NaN     1631830141-19604
# 339534                                            NaN     1631830141-19611
# 339535                                            NaN     1631830141-19612
# 339536                                            NaN     1631830141-19608
#
# ...

# %%
df=pd.read_excel("All_data_combined.xlsx")
df
# Out:
#         Unnamed: 0                                           Name  \
# 0                0    \nWorkProÂ® 1000 Series Ergonomic Mesh/Mesh
# 1                1         \nRealspaceâ¢ Anti-Fatigue Mat For...
# 2                2              \nGaiam Balance Ball Chair, Black
# 3                3  \nSertaÂ® iComfort For WorkProÂ® High-Back...
# 4                4           \nEpsonÂ® WorkForceÂ® Pro WF-3820...
# ...            ...                                            ...
# 339532      339532                                            NaN
# 339533      339533                                            NaN
# 339534      339534                                            NaN
# 339535      339535                                            NaN
# 339536      339536                                            NaN
#
#        web-scraper-start-url category  nme name  \
# 0                        NaN      NaN  NaN  NaN
# 1                        NaN      NaN  NaN  NaN
# ...

# %%
df.head()
# Out:
#                                             Name web-scraper-start-url  \
# 0    \nWorkProÂ® 1000 Series Ergonomic Mesh/Mesh                   NaN
# 1         \nRealspaceâ¢ Anti-Fatigue Mat For...                   NaN
# 2              \nGaiam Balance Ball Chair, Black                   NaN
# 3  \nSertaÂ® iComfort For WorkProÂ® High-Back...                   NaN
# 4           \nEpsonÂ® WorkForceÂ® Pro WF-3820...                   NaN
#
#   category Leaseable
# 0      NaN       NaN
# 1      NaN       NaN
# 2      NaN       NaN
# 3      NaN       NaN
# 4      NaN       NaN

# %%
df=df.drop("Unnamed: 0",axis=1)
df.shape
# Out:
# (339537, 15)

# %%
df.isnull().sum()
# Out:
# Name                         96
# web-scraper-start-url    274007
# category                 100122
# Leaseable                305249
# dtype: int64

# %%
df['Name']=df['Name'].fillna(df['nme'])

# %%
df['Name']=df['Name'].fillna(df['name'])
df=df.drop("nme",axis=1)
df=df.drop("name",axis=1)

# %%
df['Name']=df['Name'].fillna(df['nnn'])
df=df.drop("nnn",axis=1)

# %%
df['Name']=df['Name'].fillna(df['name2'])
df=df.drop("name2",axis=1)

# %%
df['Name']=df['Name'].fillna(df['nae'])
df=df.drop("nae",axis=1)

# %%
df['Name']=df['Name'].fillna(df['nn1'])
df=df.drop("nn1",axis=1)

# %%
df['Name']=df['Name'].fillna(df['nn2'])
df=df.drop("nn2",axis=1)

# %%
df['Name']=df['Name'].fillna(df['Name.1'])
df=df.drop("Name.1",axis=1)

# %%
df['Name']=df['Name'].fillna(df['note'])
df=df.drop("note",axis=1)

# %%
df['category']=df['category'].fillna(df['cat'])
df=df.drop("cat",axis=1)

# %%
df['category']=df['category'].fillna(df['catagory'])
df=df.drop("catagory",axis=1)

# %%
df['category']=df['category'].fillna(df['Category'])
df=df.drop("Category",axis=1)

# %%
df['subcategory']=df['subcategory'].fillna(df['subcat'])
df=df.drop("subcat",axis=1)

# %%
df['subcategory']=df['subcategory'].fillna(df['suncat'])
df=df.drop("suncat",axis=1)

# %%
df['category']=df['category'].fillna(df['subcategory'])
df=df.drop("subcategory",axis=1)

# %%
df.to_excel("Final_data_cleaned.xlsx")

# %%
# big_df.to_excel("all_data.xlsx")
# Out:
# C:\Users\AyanSau\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:950: UserWarning: Ignoring URL 'https://www.officedepot.com/a/browse/notebooks-and-paper/N=5+1155070/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# C:\Users\AyanSau\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:950: UserWarning: Ignoring URL 'https://www.officedepot.com/a/browse/nursing-supplies/N=5+1181133/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# C:\Users\AyanSau\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:950: UserWarning: Ignoring URL 'https://www.officedepot.com/a/browse/office-equipment/N=5+509740/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   warn("Ignoring URL '%s' since it exceeds Excel's limit of "
# ...
