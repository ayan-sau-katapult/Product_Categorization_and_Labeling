# %%
import pandas as pd

df_1=pd.read_excel("df_1.xlsx").drop("Unnamed: 0",axis=1)
df_2=pd.read_excel("df_2.xlsx").drop("Unnamed: 0",axis=1)

# %%
df_1.head()
# Out:
#                                             Name web-scraper-start-url  \
# 0    \nWorkProÂ® 1000 Series Ergonomic Mesh/Mesh                  none
# 1         \nRealspaceâ¢ Anti-Fatigue Mat For...                  none
# 2              \nGaiam Balance Ball Chair, Black                  none
# 3  \nSertaÂ® iComfort For WorkProÂ® High-Back...                  none
# 4           \nEpsonÂ® WorkForceÂ® Pro WF-3820...                  none
#
#   category Leaseable
# 0      NaN       NaN
# 1      NaN       NaN
# 2      NaN       NaN
# 3      NaN       NaN
# 4      NaN       NaN

# %%
df_2.head()
# Out:
#                                                 Name  \
# 0  Epson RapidReceipt RR-70W - Document scanner -...
# 1  EpsonÂ® ES-200 Duplex Mobile Color Document Sc...
# 2  EpsonÂ® FastFotoÂ® FF-680W High-Speed Wireless...
# 3  Epson RapidReceipt RR-60 - Document scanner - ...
# 4  EpsonÂ® PerfectionÂ® V39 Color Scanner4.1 out ...
#
#                                web-scraper-start-url  \
# 0  https://www.officedepot.com/cm/brand/epson-sca...
# 1  https://www.officedepot.com/cm/brand/epson-sca...
# 2  https://www.officedepot.com/cm/brand/epson-sca...
# 3  https://www.officedepot.com/cm/brand/epson-sca...
# 4  https://www.officedepot.com/cm/brand/epson-sca...
#
#                    category  Leaseable
# 0  Shredder-Printer-Scanner        NaN
# 1  Shredder-Printer-Scanner        NaN
# 2  Shredder-Printer-Scanner        NaN
# 3  Shredder-Printer-Scanner        NaN
# 4  Shredder-Printer-Scanner        NaN

# %%
big_df = pd.concat([df_1,df_2], ignore_index=True)

# %%
big_df.isnull().sum()
# Out:
# Name                         96
# web-scraper-start-url         0
# category                  81361
# Leaseable                305249
# dtype: int64

# %%
set(df_2["category"].tolist())
# Out:
# {'Bags and Cases',
#  'Batteries',
#  'Cutlery',
#  'Decorations',
#  'Hard-Drives-and Accessories',
#  'Laptops and Desktops',
#  'Medical Supplies',
#  'Shredder-Printer-Scanner',
#  'Stationary-Papers and Others',
#  'Television',
#  'alarm-clocks',
#  'apparel-and-protective-wears',
#  'area-rugs',
#  'artificial-plants',
#  'cables',
#  'cameras-and-camcorders',
#  'chairs',
#  'coat-hooks-racks-and-hangers',
#  'conferencing',
#  'custom-tablecloths',
#  'easels-and-pads',
#  'education-software',
#  'enclosed-boards',
#  'ergonomic-protection',
#  'eye-protection',
#  'finance-and-legal-software',
#  'fire-gas-and-water-protection',
#  'food-items',
#  'hearing-aids',
#  'hot-and-cold-therapy',
#  'instructional-resources',
#  'kitchen-and-home-appliances',
#  'lamps-and-lighting',
#  'light-therapy-lamps',
#  'lightbox-displays',
#  'marketing-materials',
#  'media',
#  'metal-signs',
#  'mirrors',
#  'mounting-supplies',
#  'murals',
# ...

# %%
def categorize(string):
    string= "".join(str(string).split()).lower()
    if "laptop" in string or "desktop" in string or "book" in string or "touchscreen" in string and "backpack" not in string and "stand" not in string and "mount" not in string and "case" not in string:
        return "Laptops and Desktops"
    elif "clock" in string:
        return "alarm-clocks"
    elif "batter" in string or "charge" in string:
        return "Batteries"
    elif "rug" in string:
        return "area-rugs"
    elif "nearlynatural" in string or "plant" in string or "artificial" in string or "tree" in string or "pot" in string:
        return "artificial-plants"
    elif "audio" in string or "sound" in string or "speaker" in string or "woof" in string or "bluetooth" in string or "headphones" in string or "ear" in string or "bud" in string or "amplifier" in string or "stereo" in string or "ipod" in string or "head" in string or "mic" in string:
        return "speakers-and-headsets"
    elif "frame" in string or "strip" in string or "hook" in string or "set" in string or "stand" in string or "mount" in string or "height" in string or "adjust" in string or "pivot" in string or "support" in string or "arm" in string or "cart" in string or "pod" in string or "deck" in string or "panel" in string:
        return "mounting-supplies"
    elif "cover" in string or "skin" in string or "sleeve" in string or "slip" in string or "briefcase" in string or "tote" in string or "lunch" in string or "contain" in string or "backpack" in string or "bag" in string or "box" in string or "tumbl" in string or "bottle" in string or "sling" in string or "case" in string:
        return "Bags and Cases"
    elif "syringe" in string or "pain" in string or "tablet" in string or "tourniquets" in string or "medical" in string or "aid" in string or "embol" in string or "stock" in string or "cotton" in string or "swab" in string or "bandage" in string or "dressings" in string or "wrap" in string or "wound" in string:
        return "Medical Supplies"
    elif "cray" in string or "menu" in string or "folder" in string or "bind" in string or "divide" in string or "multi" in string or "letter" in string or "book" in string or "tape" in string or "sheet" in string or "note" in string or "label" in string or "stick" in string or "cartridge" in string or"ink" in string or "stationery" in string or "pad" in string or "seal" in string or "envelope" in string or "stamp" in string or "flag" in string or "calendar" in string or "plan" in string or "kit" in string or "book" in string or "shel" in string or "cabinet" in string or "liquid" in string or "holder" in string or "hook" in string or "shelf" in string or "board" in string or "chalk" in string or "mark" in string or "erase" in string or "paper" in string or "glue" in string or "adhesive" in string or "tape" in string or "cleaner" in string or "sponge" in string or "paper" in string or "card" in string or "note" in string or "label" in string or "foam" in string or "sheet" in string or "staple" in string or "note" in string or "pen" in string or "pencil" in string or "erase" in string or "sharp" in string or "ruler" in string or "scissor" in string or "sanitize" in string:
        return "Stationary-Papers and Others"
    elif "brac" in string or "tv" in string  or "led" in string or "lcd" in string and "backpack" not in string and "stand" not in string and "mount" not in string:
        return "Television"
    elif "scan" in string or "print" in string or "shredder" in string or "project" in string:
        return "Shredder-Printer-Scanner"
    elif "babymonitor" in string or "photo" in string or "cam" in string or "lens" in string or "camera" in string or "gopro" in string and "clean" not in string and "stand" not in string and "mount" not in string:
        return "cameras-and-camcorders"
    elif "chair" in string:
        return "chairs"
    elif "gb" in string or "ram" in string or "memory" in string or "module" in string or "port" in string or "dock" in string or "adapt" in string or "power" in string or "cd" in string or "dvd" in string or "drive" in string or "signal" in string or "cell" in string or "phone" in string or "mouse" in string or "key" in string and "book" not in string and "laptop" not in string and "desktop" not in string:
        return "Hard-Drives-and Accessories"
    elif "cable" in string or "usb" in string or "adapter" in string or "hdmi" in string or "convert" in string or "port" in string:
        return "cables"
    elif "extinguishers" in string or "glasses" in string or "protect" in string or "safety" in string or "wear" in string or "ghent" in string or "support" in string or "back" in string or "wallet" in string or "coat" in string or "mouth" in string or "ergodyne" in string or "chin" in string or "strap" in string or "shield" in string or "hard" in string or "helmet" in string or "shade" in string or "gown" in string or "mask" in string or "band" in string or "cap" in string or "face" in string or "hat" in string or "skull" in string or "foot" in string or "icetraction" in string or"small" in string or "medium" in string or "large" in string or "towel" in string or "pant" in string or "apron" in string or "hood" in string or "ergodynegloWear" in string or "glove" in string or "jacket" in string or "shirt" in string or "suit" in string or "napkin" in string or "coverall" in string or "eye" in string or "knee" in string or "elbow" in string or "ankle" in string:
        return "apparel-and-protective-wears"
    elif "mural" in string or "borod" in string or "tablecover" in string or "ampersand" in string or "display" in string or "clay" in string or "wall" in string or "post" in string or "art" in string or "frame" in string or "floor" in string or "decal" in string or "sign" in string or "motiv" in string:
        return "Decorations"
    elif "phone" in string or "grinder" in string or "dishwasher" in string or "vent" in string or "steam" in string or "fabric" in string or "dry" in string or "filter" in string or "aircon" in string or "fan" in string or "cooler" in string or "cool" in string or "humid" in string or "heat" in string or "air" in string or "iron" in string or "cook" in string or "toast" in string or "oven" in string or "dispense" in string or "maker" in string or "grill" in string or "micro" in string or "fryer" in string or "blender" in string or "process" in string:
        return "kitchen-and-home-appliances"
    elif "plate" in string or "fork" in string or "spoon" in string or "cutlery" in string or "Knive" in string or "cup" in string or "oz" in string or "box" in string or "bowl" in string or "utensil" in string or "dish" in string and "dishwasher" not in string:
        return "Cutlery"
    elif "animal" in string or "trap" in string or "fly" in string or "bug" in string or "kill" in string or "repellent" in string or "spray" in string or "clean" in string or "soap" in string or "gel" in string or "pad" in string or "paste" in string or "moist" in string:
        return "repellents-cleaning-and-sanitary-products"
    elif "mix" in string or "marsh" in string or "food" in string or "drink" in string or "choco" in string or "shake" in string or "smooth" in string or "fruit" in string or "berry" in string or "water" in string or "eyewash" in string or "eye" in string or "juice" in string or "lemon" in string or "punch" in string or "oz" in string:
        return "food-items"
    elif "mirror" in string or "hanger" in string or "hook" in string:
        return "furniture"
    elif "lamp" in string or "light" in string or "led" in string:
        return "lighting"
    elif "alarm" in string or "sensor" in string or "motion" in string or "detect" in string:
        return "electronics"
    else:
        return "software"

# %%
big_df = pd.concat([df_1,df_2], ignore_index=True)

# %%
big_df["category"]=big_df["Name"].apply(categorize)
big_df.shape
# Out:
# (339537, 4)

# %%
big_df.isnull().sum()
# Out:
# Name                         96
# web-scraper-start-url         0
# category                      0
# Leaseable                305249
# dtype: int64

# %%
def is_leasable(string):
    if string=="Laptops and Desktops" or string=="Shredder-Printer-Scanner" or string=="Television" or string=="cameras-and-camcorders" or string=="chairs" or string=="cables" or string=="electronics" or string=="furniture" or string=="kitchen-and-home-appliances" or  string=="speakers-and-headsets":
        return "TRUE"
    else:
        return "FALSE"

# %%
big_df["Leaseable"]=big_df["category"].apply(is_leasable)

# %%
big_df.to_excel("office_depot_final.xlsx")

# %%
big_df.groupby("category").count()
# Out:
#                                             Name  web-scraper-start-url  \
# category
# Bags and Cases                             27414                  27414
# Batteries                                   3932                   3932
# Cutlery                                     3524                   3524
# Decorations                                 4089                   4089
# Hard-Drives-and Accessories                14262                  14262
# Laptops and Desktops                       24013                  24013
# Medical Supplies                            5312                   5312
# Shredder-Printer-Scanner                    3862                   3862
# Stationary-Papers and Others               71910                  71910
# Television                                  4508                   4508
# alarm-clocks                                1060                   1060
# apparel-and-protective-wears                6428                   6428
# ...
