# %%
import glob
import pandas as pd

# get data file names
path =r'C:\Users\AyanSau\Desktop\ABESofMAINE_ALLparsedFILES\ABESofMAINE_All_Files'
filenames = glob.glob(path + "/*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))

# Concatenate all data into one DataFrame
big_df = pd.concat(dfs, ignore_index=True)
big_df
# Out:
#      web-scraper-order                              web-scraper-start-url  \
# 0         1635553500-2  https://www.abesofmaine.com/Computers/Accessor...
# 1         1635553500-1  https://www.abesofmaine.com/Computers/Accessor...
# 2       1635602110-106  https://www.abesofmaine.com/Large_Appliances/V...
# 3        1635559996-61  https://www.abesofmaine.com/Large_Appliances/B...
# 4        1635559996-62  https://www.abesofmaine.com/Large_Appliances/B...
# ...                ...                                                ...
# 3812    1635500596-512  https://www.abesofmaine.com/Store/TV_s_Enterta...
# 3813    1635500596-514  https://www.abesofmaine.com/Store/TV_s_Enterta...
# 3814    1635500596-511  https://www.abesofmaine.com/Store/TV_s_Enterta...
# 3815    1635500596-510  https://www.abesofmaine.com/Store/TV_s_Enterta...
# 3816    1635500596-515  https://www.abesofmaine.com/Store/TV_s_Enterta...
#
#            brand                                               name    price  \
# ...

# %%
big_df.isnull().sum()
# Out:
# web-scraper-order        1883
# web-scraper-start-url    1883
# brand                    1967
# name                     1883
# price                    1883
# Brand                    2018
# Name                     1934
# Price                    1934
# Category                 1934
# Leasable                 3817
# dtype: int64

# %%
big_df["name"]=big_df["name"].fillna(big_df["Name"])
big_df["price"]=big_df["price"].fillna(big_df["Price"])

# %%
big_df.isnull().sum()
# Out:
# web-scraper-order        1883
# web-scraper-start-url    1883
# brand                    1967
# name                        0
# price                       0
# Brand                    2018
# Name                     1934
# Price                    1934
# Category                 1934
# Leasable                 3817
# dtype: int64

# %%
big_df=big_df[["name","price","Category","Leasable"]]
big_df
# Out:
#                                                    name    price Category  \
# 0     Logitech M510 Wireless Computer Mouse Comforta...   $20.00      NaN
# 1     Logitech Type+ Protective iPad Air 2 Case with...   $79.00      NaN
# 2                          VTR1030D - Remote Ventilator  $649.00      NaN
# 3                                         Premium Cover   $26.35      NaN
# 4     Smoker Box For Use with Any Built-In or Freest...  $113.00      NaN
# ...                                                 ...      ...      ...
# 3812                            12FT HDMI OLED/4K Cable  $149.99      NaN
# 3813                     50" HDMI CABLE 24K GOLD TIPPED  $199.00      NaN
# 3814  DisplayPort to DisplayPort 6 Feet Cable, DP to...   $79.00      NaN
# 3815                             6FT HDMI OLED/4K Cable   $79.00      NaN
# 3816                      Premium 4K 25 FOOT HDMI Cable  $199.99      NaN
#
#       Leasable
# 0          NaN
# 1          NaN
# 2          NaN
# ...

# %%
big_df.to_excel("big_df.xlsx")

# %%
def categorize(string):
    
    string= "".join(str(string).split()).lower()
    if "mouse" in string or "keyboard" in string:
        return "Desktop Accessories"
    elif "cooktop" in string or "glass" in string or "steel" in string:
        return "CookWare"
    elif "oven" in string or "grill" in string or "washer" in string or "microwave" in string:
        return "Home Appliances"
    elif "port" in string or "router" in string or "cable" in string or "ethernet" in string or "switch" in string or "transceiver" in string or "swtch" in string:
        return "Routers and Cables"
    elif "video" in string or "cam" in string and "len" not in string and "case" not in string and "bag" not in string and "pouch" not in string:
        return "Cameras"
    elif "batter" in string:
        return "Batteries"
    elif "filter" in string or "lens" in string or "tripod" in string and "cam" not in string or "grip" in string or "mirror" in string or "macro" in string or "hsm" in string or "extend" in string or "zoom" in string or "convert" in string or "ring" in string:
        return "Camera Accessories"
    elif "case" in string or "pouch" in string or "bag" in string and "cam" not in string and "lens" not in string or "cover" in string:
        return "Bags and Cases"
    elif "charger" in string or "adapt" in string:
        return "Chargers and Adapters"
    elif "card" in string or "gb" in string:
        return "Memory Cards and Graphic Cards"
    elif "tv" in string and "mount" not in string:
        return "TV"
    elif "mount" in string:
        return "Mount"
    elif "phone" in string:
        return "Phones"
    elif "project" in string:
        return "Projector"
    elif "think" in string:
        return "Laptop"
    else:
        pass

# %%
big_df["Category"]=big_df["name"].apply(categorize)
big_df.to_excel("ABESofMAINE_trial.xlsx")
# Out:
# <ipython-input-22-fe56d8f6d400>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   big_df["Category"]=big_df["name"].apply(categorize)
