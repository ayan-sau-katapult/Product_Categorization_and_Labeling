# %%
import pandas as pd

df=pd.read_csv("final-lovesac.csv")
df
# Out:
#                                        productName             category
# 0           Throw Pillow Cover: Diamond Slub 24x16  lovesac-accessories
# 1                Sactionals Guest Rest Bedding Kit  lovesac-accessories
# 2              Sactionals Mini Blocks Set: Natural  lovesac-accessories
# 3                             Sactionals Power Hub  lovesac-accessories
# 4                   Footsac Blanket: Sodalite Phur  lovesac-accessories
# ..                                             ...                  ...
# 208                Sactionals Coaster: Dark Walnut          Accessories
# 209  Sactionals Roll Arm Drink Holder: Dark Walnut          Accessories
# 210                              7 Seats + 8 Sides              Outdoor
# 211                              4 Seats + 5 Sides              Outdoor
# 212                             8 Seats + 10 Sides              Outdoor
#
# [213 rows x 2 columns]
